# %% [markdown]
# <a href="https://colab.research.google.com/github/bwubuw/Auto-GPT/blob/master/Exercise1_Introduction_template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise - Introduction to Deep Learning <a class="tocSkip">

# %% [markdown]
# Welcome to our first exercise. Today we are gonna talk about deep learning basics and some important Python libraries which are commonly used.

# %% [markdown]
# ## Warm-up questions

# %% [markdown]
# **Question 1:** Which of the following is a limitation of supervised learning?
#
# - It requires labeled data
# - It is not suitable for classification tasks
# - It is not suitable for regression tasks
# - It cannot be used with deep neural networks

# %% [markdown]
# <ul>
#
# *Your solution*
#
# </ul>

# %% [markdown]
# **Question 2:** Which of the following learning paradigms involves finding hidden structure in unlabeled data?
#
# - Supervised Learning
# - Unsupervised Learning
# - Reinforcement Learning
# - Semi-Supervised Learning

# %% [markdown]
# <ul>
#
# *Your solution*
#
# </ul>

# %% [markdown]
# **Question 3:** Which of the following is a typical application of unsupervised learning?
#
# - Speech Recognition
# - Clustering
# - Object Detection
# - Sentiment Analysis

# %% [markdown]
# <ul>
#
# *Your solution*
#
# </ul>

# %% [markdown]
# **Question 4:** What is the goal of reinforcement learning?
#
# - To cluster data points based on their similarity
# - To reduce the dimensionality of data
# - To find the optimal policy that maximizes a reward signal
# - To classify data into different categories

# %% [markdown]
# <ul>
#
# *Your solution*
#
# </ul>

# %% [markdown]
# **Question 5:** What is the chain rule used for in calculus?
#
# - Finding the maximum or minimum of a function
# - Calculating the derivative of a composition of functions
# - Evaluating integrals
# - Solving differential equations

# %% [markdown]
# <ul>
#
# *Your solution*
#
# </ul>

# %% [markdown]
# ## Deep learning - the basics

# %% [markdown]
# Please describe in your own words how a (machine) learning model learns. What are the prerequisites? What and how does the model learn?

# %% [markdown]
# <ul>
#
# *Your solution*
#
# </ul>

# %% [markdown]
# Please name and describe the three main learning paradigms in deep learning.

# %% [markdown]
# <ul>
#
# *Your solution*
#
# </ul>

# %% [markdown]
# What is the chain rule?

# %% [markdown]
# <ul>
#
# *Your solution*
#
# </ul>

# %% [markdown]
# What is the gradient of a function $f(x_1, x_2, ..., x_n)$ with respect to a set of variables $x_1, x_2, ..., x_n$, and how are partial derivatives used to calculate it?

# %% [markdown]
# <ul>
#
# *Your solution*
#
# </ul>

# %% [markdown]
# ## Math fundamentals

# %% [markdown]
# Calculate the gradient of the following function with respect to $x$ and $y$:
#
# $$
# f(x, y) = 3x^2 + 4xy - 2y^3
# $$

# %% [markdown]
# <ul>
#
# *Your solution*
#
# </ul>

# %% [markdown]
# Given are the following functions: $f(x) = sin(x^2)$ and $g(x) = x^3 - 2x$. Calculate $\frac{d f(g(x))}{d x}$.

# %% [markdown]
# <ul>
#
# *Your solution*
#
# </ul>

# %% [markdown]
# ## Machine Learning Basics - Scikit-Learn and Matplotlib

# %% [markdown]
# In this exercise, the **Iris Flower dataset** known from the lecture **will be analyzed**. Two libraries (**[Scikit-Learn](https://scikit-learn.org/stable/)** and **[Matplotlib](https://matplotlib.org/)**) will be introduced, which help to create and train the learning models and to visualize the results.
#
# **Documentation** for both libraries can be found at:
# - [Scikit-Learn Documentation](https://scikit-learn.org/stable/documentation.html)
# - [Matplotlib Documentation](https://matplotlib.org/contents.html)

# %% [markdown]
# ### Imports

# %%
import numpy as np

# %% [markdown]
# ### Iris Flower dataset

# %% [markdown]
# **Download the Iris Flower dataset** and familiarize yourself with its properties. The dataset is available in Scikit-Learn.

# %%
from sklearn import datasets
iris = datasets.load_iris()

# %% [markdown]
# Examine the object that contains the data and answer the following questions.

# %% [markdown]
# #### Classes and datapoints

# %% [markdown]
# Please write the necessary code to answer the following questions:
# - How many classes are there?
# - What are the names of the classes?
# - How many data points per class are there?
#
# <a class="codeSolutionNextReplace">

# %%
# Your solution

# %% [markdown]
# #### Features

# %% [markdown]
# Please write the necessary code to answer the following questions:
# - How many features are there?
# - What names do the features have?
# - How are the individual features expressed? (Minimum value, maximum value, mean value, standard deviation).
#
# <a class="codeSolutionNextReplace">

# %%
# Your solution

# %% [markdown]
# #### Feature expression

# %% [markdown]
# **Visualize the expression of the features in a histogram.** Use Matplotlib for the visualization. The following minimal example shows the use of the function.

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.random.normal(0, 1, 1000)
plt.hist(data)
plt.show()

# %% [markdown]
# Define a function ``plot_hist`` which creates the histogram.
#
# <a class="codeSolutionNextReplace">

# %%
# Your solution

# %% [markdown]
# You can check your function with the following code snippet:

# %%
plot_hist(iris.data, iris.target)

# %% [markdown]
# #### Correlations

# %% [markdown]
# **Visualize the correlations between each feature in a scatterplot**. Plot each feature against each other and get an overview of which features could be crucial for a prediction. Use Matplotlib again for the visualization. The following minimal example shows the use of the scatterplot function.

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.random.normal(0, 1, (100, 2))
plt.scatter(data[:, 0], data[:, 1])
plt.show()

# %% [markdown]
# Define a function ``plot_scatter`` which creates the scatterplot.
#
# <a class="codeSolutionNextReplace">

# %%
# Your solution

# %% [markdown]
# You can check your function with the following code snippet:

# %%
plot_scatter(iris.data, iris.target)

# %% [markdown]
# ### Predictions for new Iris Flowers

# %% [markdown]
# For the following tasks we will again utilize the Iris Flowers dataset provided by Scikit-Learn.

# %%
from sklearn import datasets
iris = datasets.load_iris()

# %% [markdown]
# #### Principal component analysis

# %% [markdown]
# Prepare the data to train and evaluate a classification model. First, **reduce the number of features from 4 to 2** so that the results can be easily visualized later. For this purpose, **perform a [Principal Component Analysis](https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html)** and consider only the first two Principal Components for further analysis. PCA is available directly in Scikit-Learn. The following minimal example shows how to use the function.

# %%
import numpy as np
from sklearn.decomposition import PCA

X = np.random.normal(42, 2.0, (100, 7))
pca = PCA(n_components=2)
X_transformed = pca.fit_transform(X)

print(X.shape)
print(X_transformed.shape)
# Out:
# (100, 7)
# (100, 2)

# %% [markdown]
# Now, perform the PCA for the Iris Flowers Dataset and store the result in a variable named ``iris_transformed``.
#
# <a class="codeSolutionNext">

# %%
# Your solution
# Out:
# Original shape: (150, 4), new shape: (150, 2)

# %% [markdown]
# #### Data split

# %% [markdown]
# After the transformation, **split the data into a training and test dataset**. Use the function implemented in Scikit-Learn for this. The following minimal example shows how to use the function.

# %%
from sklearn.model_selection import train_test_split

X, y = np.arange(10).reshape((5, 2)), range(5)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# Use the same labels as in the given example and split the ``iris_transformed`` data accordingly.
#
# <a class="codeSolutionNext">

# %%
# Your solution
# Out:
# X_train shape: (105, 2), X_test shape: (45, 2), y_train shape: (105,), y_test shape: (45,)

# %% [markdown]
# #### K-Nearest-Neighbor

# %% [markdown]
# Create a **[K-Nearest-Neighbor](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html) classification model** and train the model using the training data. **Validate the model accuracy** using the test data. The following minimal example shows the creation, training, and testing of a model.

# %%
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.model_selection import cross_validate

clf = KNN(n_neighbors=3)
clf.fit(X_train, y_train)
score = clf.score(X_test, y_test)

# %% [markdown]
# Create the **K-Nearest-Neighbor classification models** and gather the **evaluation data**. Create models for a range of ``n_neighbors = n`` with $n = [1, 50]$.
#
# **Make sure that the output** of your algorithm **fits the given plot function** underneath.
#
# <a class="codeSolutionNext">

# %%
# Your solution

# %% [markdown]
# Utilize the following function to **plot the evaluation results**.

# %%
def plot_scores(_neighbors_list, _neighbor_scores):
    fig = plt.figure(figsize=(12, 6))
    ax1 = fig.add_subplot(211)
    ax2 = fig.add_subplot(212)
    ax1.plot(_neighbors_list, _neighbor_scores[:, 0], label="Training accuracy")
    ax1.plot(_neighbors_list, _neighbor_scores[:, 1], label='Test accuracy')
    ax2.plot(_neighbors_list, _neighbor_scores[:, 2], label="Cross validated training accuracy")
    ax2.plot(_neighbors_list, _neighbor_scores[:, 3], label='Cross validated test accuracy')
    for ax in [ax1, ax2]:
        ax.set_xticks(_neighbors_list)
        ax.set_xlabel("Number of nearest neighbors")
        ax.set_ylabel("Accuracy")
        ax.legend()
    plt.tight_layout()
    plt.show()

# %%
plot_scores(neighbors_list, neighbor_scores)

# %% [markdown]
# #### Prediction for new set

# %% [markdown]
# Make a **prediction for a set of new Iris Flowers**. First create a small dataset of new data points with four features but make sure these features are in the correct value range. You can utilize the given `iris_feature_stats` function for this purpose.

# %%
def iris_feature_stats():
    feature_stats = np.zeros((4, 4))
    for i_feature in range(4):
        feature_stats[i_feature] = (np.min(iris.data[:, i_feature]),
                                    np.max(iris.data[:, i_feature]),
                                    np.mean(iris.data[:, i_feature]),
                                    np.std(iris.data[:, i_feature]))
    return feature_stats

# %% [markdown]
# Define the amount of new data points you want to add to the set.

# %%
n_new_data_points = 20

# %% [markdown]
# Utilize the extracted feature statistics to generate the requested amount of additional (plausible) data points.
#
# <a class="codeSolutionNext">

# %%
# Your solution
# Out:
# Shape of new data points array: (20, 4)

# %% [markdown]
# Keep in mind that your model was trained in reduced feature space. First reduce your new data points with the already trained PCA model.
#
# <a class="codeSolutionNext">

# %%
# Your solution
# Out:
# Shape of new data points array after PCA: (20, 2)

# %% [markdown]
# Now, train a KNN (e.g. with `n_neighbors=20`) using the training data set. Once trained, get a class prediction vector for the new data points.
#
# <a class="codeSolutionNext">

# %%
# Your solution
# Out:
# Prediction for new data points: [2 2 1 0 0 1 1 2 0 1 1 1 0 1 1 2 1 2 1 2]
# with the classes: '0' - setosa, '1' - versicolor, '2' - virginica

# %% [markdown]
# #### Visualization

# %% [markdown]
# Run the following code cells to generate a visualization of the classification.

# %%
def visualize(model, X, y, X_new=None, y_new=None):
    # create a mesh grid
    h = 0.02
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))

    # save the decision boundary of the model.
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    # add some random noise to the data for plotting purposes only so that overlapping points can be identified.
    noise = np.random.normal(0, 0.02, X.shape)
    X = X + noise

    # create a custom colormap that maps a specific color to each flower class
    cmap = plt.cm.coolwarm
    colors = cmap(np.linspace(0, 1, 3, endpoint=True))

    # set the size of the figure
    plt.rcParams["figure.figsize"] = (10, 6)

    # plot the decision boundary of the model in color code
    plt.contourf(xx, yy, Z, cmap=cmap, alpha=0.5)

    # plot the data points for each flower class
    for i_class in np.unique(y):
        plt.scatter(X[:, 0][y == i_class], X[:, 1][y == i_class],
                    s=64, c=np.atleast_2d(colors[i_class]), edgecolor='k', alpha=0.7,
                    label=iris['target_names'][i_class])

    if X_new is not None and y_new is not None:
        for i_class in np.unique(y_new):
            plt.scatter(X_new[:, 0][y_new == i_class],
                        X_new[:, 1][y_new == i_class],
                        marker='^', s=96, c=np.atleast_2d(colors[i_class]),
                        edgecolor='k', alpha=0.7)

    # set plotting parameters such as axis labels, ranges, a title and the legend.
    plt.xlabel('PC1')
    plt.ylabel('PC2')
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.title('KNN Classification')
    plt.legend()

    # show the plot
    plt.show()

# %%
visualize(clf, X_train, y_train, X_new_trans, y_new)

# %% [markdown]
# ---

# %% [markdown]
# **Last update:** 2023-04-11
#
# **Version:** 2.0

# %% [markdown]
# **Copyright** © Bergische Universität Wuppertal
